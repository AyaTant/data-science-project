# %%
import pandas as pd
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\ayata\\OneDrive\\MLOPS\\data-science-project\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\ayata\\OneDrive\\MLOPS\\data-science-project'

# %%
from dataclasses import dataclass
from pathlib import Path
@dataclass
class DataTransformationConfig:
    root_dir:Path
    STATUS_FILE:Path
    unzip_data_dir:Path
    all_schema:dict
