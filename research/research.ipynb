# %% [markdown]
# #### This notebook is just used as a reference for understanding any new knowledge

# %%
example={"key1":"value1",
        "key2":"value2"}

# %%
example["key1"]
# Out:
# 'value1'

# %%
example.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 example.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
from box import ConfigBox

# %%
example= ConfigBox({"key1":"value1",
        "key2":"value2"})
example.key1
# Out:
# 'value1'

# %%
## Explanation for ensure annotations

def get_product(x:int,y:int) ->int:
    return x*y

# %%
get_product(2,2)
# Out:
# 4

# %%
get_product(2,"4")
# Out:
# '44'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int,y:int) ->int:
    return x*y

# %%
get_product("5",2)
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 get_product("5",2)
#
# File c:\Users\ayata\OneDrive\MLOPS\data-science-project\dataproject\lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument x of type <class 'str'> to <function get_product at 0x0000024F2C80A050> does not match annotation type <class 'int'>
